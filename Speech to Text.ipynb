# %%
# !pip3 install git+https://github.com/huggingface/transformers -q
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip

# %%
from transformers import pipeline
import torch

if torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

whisper = pipeline('automatic-speech-recognition', model='openai/whisper-medium', device=device)

# %%
audio_path = '/Users/propelld/Downloads/SELF-INTRODUCTION VIDEO  30 SECONDS.mp3'

display(Audio(audio_path, autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
text = whisper(audio_path,return_timestamps = True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(

# %%
text
# Out:
# {'text': " Hello, my name is Patricia Espiritu. I am 24 years old from the Philippines. I have a bachelor's degree in business administration major in financial management and I have a TESOL and TEFL certification. I am a bank employee for almost four years now where I was at customer service for two years. I love teaching kids and I'm very excited to make a great impact in your company. Thank you.",
#  'chunks': [{'timestamp': (0.0, 8.6),
#    'text': ' Hello, my name is Patricia Espiritu. I am 24 years old from the Philippines. I have'},
#   {'timestamp': (8.6, 12.9),
#    'text': " a bachelor's degree in business administration major in financial"},
#   {'timestamp': (12.9, 18.8),
#    'text': ' management and I have a TESOL and TEFL certification. I am a bank employee for'},
#   {'timestamp': (18.8, 24.3),
#    'text': ' almost four years now where I was at customer service for two years. I love'},
#   {'timestamp': (24.3, 29.3),
# ...
